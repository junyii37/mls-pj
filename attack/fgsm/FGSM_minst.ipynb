# %%
import argparse
import sys
from torchvision.datasets import MNIST
from mynn.data import mnist_augment, preprocess, basic_mnist_augment, merge_datasets
from mynn.layer import Flatten, Linear, ReLU, He, Conv, Dropout, Pooling, BN,Sigmoid
from mynn.loss import CrossEntropy
from mynn import Model
from mynn.optimizer import SGD, Adam, MomentGD
from mynn.runner import RunnerM, EarlyStopping, CosineAnnealingLR
import cupy as cp

# %%
cp.random.seed(42)

train_dataset = MNIST(
        root="dataset",
        train=True,
        transform=basic_mnist_augment(train=True),
        download=False
    )
test_dataset = MNIST(
    root="dataset",
    train=False,
    transform=basic_mnist_augment(train=False),
    download=False
)

# %%
import numpy as np
train_images, train_labels = preprocess(train_dataset)
test_images,  test_labels  = preprocess(test_dataset)
# 
# train_images = train_images.astype(np.float32) / 255.0
# test_images = test_images.astype(np.float32) / 255.0

train_set = (train_images[:50000], train_labels[:50000])

dev_set   = (train_images[50000:], train_labels[50000:])
test_set  = (test_images, test_labels)

# %%
print(train_images.shape, train_labels.shape)
# Out:
# (60000, 1, 28, 28) (60000, 10)

# %%
import numpy as np
print("Min pixel value:", np.min(test_images))
print("Max pixel value:", np.max(test_images))
# Out:
# Min pixel value: 0.0
# Max pixel value: 1.0

# %%
layers = [
    Conv(in_channel=1, out_channel=6, kernel=3, stride=1, padding=1, weight_decay=0.00),
 
    Sigmoid(),
    Pooling(kernel=2),

    Conv(in_channel=6, out_channel=16, kernel=3, stride=1, padding=1, weight_decay=0.00),
   
    Sigmoid(),
    Pooling(kernel=2),

    Flatten(),
    

    Linear(in_channel=16*7*7, out_channel=120, weight_decay=0.00),
    Linear(in_channel=120, out_channel=84, weight_decay=0.00),
    Linear(in_channel=84, out_channel=10, weight_decay=0.00),
]

# %%
model     = Model(layers)
optimizer = Adam(model=model, lr=0.001)
loss_fn   = CrossEntropy(model=model)
runner    = RunnerM(model=model, loss=loss_fn, optimizer=optimizer)

# %%
# 3. 训练
runner.train(
    train_set=train_set,
    dev_set=dev_set,
    batch_size=64,
    num_epochs=15,
    scheduler=CosineAnnealingLR(
        optimizer=optimizer,
        T_max=5,
            eta_min=1e-5,
    ),
    strategy=EarlyStopping(
        patience=5,
        delta=0.0,
    ),
    shuffle=True,
    save_dir='best_model_basic'
)
# Out:
# Epoch 1/15: 100%|██████████| 782/782 [00:21<00:00, 36.68batch/s, accuracy=0.875, loss=0.254]
# train_loss: 0.24343, train_acc: 0.92746
# dev_loss  : 0.21954, dev_acc  : 0.93750
# ### Best model saved to: best_model_basic\2025-05-22_19-39-32\best_model.pickle
# ### Best validation accuracy updated: 0.00000 -> 0.93750
# Patience Counter Reset to 0
#
# Epoch 2/15: 100%|██████████| 782/782 [00:20<00:00, 38.51batch/s, accuracy=1, loss=0.0571]
# train_loss: 0.18102, train_acc: 0.94337
# dev_loss  : 0.17289, dev_acc  : 0.95010
# ### Best model saved to: best_model_basic\2025-05-22_19-39-32\best_model.pickle
# ### Best validation accuracy updated: 0.93750 -> 0.95010
# Patience Counter Reset to 0
#
# Epoch 3/15: 100%|██████████| 782/782 [00:20<00:00, 38.36batch/s, accuracy=1, loss=0.0396]
# train_loss: 0.11013, train_acc: 0.96529
# dev_loss  : 0.10333, dev_acc  : 0.96953
# ### Best model saved to: best_model_basic\2025-05-22_19-39-32\best_model.pickle
# ### Best validation accuracy updated: 0.95010 -> 0.96953
# Patience Counter Reset to 0
#
# Epoch 4/15: 100%|██████████| 782/782 [00:20<00:00, 38.23batch/s, accuracy=1, loss=0.0715]
# train_loss: 0.09101, train_acc: 0.97094
# dev_loss  : 0.08965, dev_acc  : 0.97451
# ### Best model saved to: best_model_basic\2025-05-22_19-39-32\best_model.pickle
# ### Best validation accuracy updated: 0.96953 -> 0.97451
# Patience Counter Reset to 0
#
# Epoch 5/15: 100%|██████████| 782/782 [00:20<00:00, 37.52batch/s, accuracy=1, loss=0.0215]
# train_loss: 0.07208, train_acc: 0.97724
# dev_loss  : 0.07680, dev_acc  : 0.97793
# ### Best model saved to: best_model_basic\2025-05-22_19-39-32\best_model.pickle
# ### Best validation accuracy updated: 0.97451 -> 0.97793
# Patience Counter Reset to 0
#
# Epoch 6/15: 100%|██████████| 782/782 [00:20<00:00, 37.87batch/s, accuracy=1, loss=0.00272]
# train_loss: 0.06850, train_acc: 0.97871
# dev_loss  : 0.07416, dev_acc  : 0.97930
# ### Best model saved to: best_model_basic\2025-05-22_19-39-32\best_model.pickle
# ### Best validation accuracy updated: 0.97793 -> 0.97930
# Patience Counter Reset to 0
#
# Epoch 7/15: 100%|██████████| 782/782 [00:19<00:00, 39.40batch/s, accuracy=0.938, loss=0.606]
# train_loss: 0.06681, train_acc: 0.97925
# dev_loss  : 0.07130, dev_acc  : 0.97949
# ### Best model saved to: best_model_basic\2025-05-22_19-39-32\best_model.pickle
# ### Best validation accuracy updated: 0.97930 -> 0.97949
# Patience Counter Reset to 0
#
# Epoch 8/15: 100%|██████████| 782/782 [00:19<00:00, 39.31batch/s, accuracy=1, loss=0.00405]
# train_loss: 0.06719, train_acc: 0.97933
# dev_loss  : 0.07155, dev_acc  : 0.97979
# ### Best model saved to: best_model_basic\2025-05-22_19-39-32\best_model.pickle
# ### Best validation accuracy updated: 0.97949 -> 0.97979
# Patience Counter Reset to 0
#
# Epoch 9/15: 100%|██████████| 782/782 [00:19<00:00, 39.10batch/s, accuracy=1, loss=0.0134]
# train_loss: 0.07184, train_acc: 0.97722
# dev_loss  : 0.08048, dev_acc  : 0.97627
# Patience: 1/5
#
# Epoch 10/15: 100%|██████████| 782/782 [00:19<00:00, 39.78batch/s, accuracy=0.875, loss=0.205]
# train_loss: 0.09826, train_acc: 0.96889
# dev_loss  : 0.10401, dev_acc  : 0.97021
# Patience: 2/5
#
# Epoch 11/15: 100%|██████████| 782/782 [00:20<00:00, 38.15batch/s, accuracy=1, loss=0.0264]
# train_loss: 0.06989, train_acc: 0.97819
# dev_loss  : 0.07789, dev_acc  : 0.97822
# Patience: 3/5
#
# Epoch 12/15: 100%|██████████| 782/782 [00:21<00:00, 36.97batch/s, accuracy=1, loss=0.0106]
# train_loss: 0.06916, train_acc: 0.97700
# dev_loss  : 0.07854, dev_acc  : 0.97695
# Patience: 4/5
#
# Epoch 13/15: 100%|██████████| 782/782 [00:21<00:00, 36.57batch/s, accuracy=0.938, loss=0.083]
# train_loss: 0.06882, train_acc: 0.97713
# dev_loss  : 0.08387, dev_acc  : 0.97676
# Patience: 5/5
#
# Early Stopping Triggered.

# %%
# 4. 测试集评估
test_loss, test_acc = runner.evaluate(test_set, batch_size=64,loss_fn=loss_fn)
print(f"Test loss: {test_loss:.5f}, Test accuracy: {test_acc:.5f}")
# Out:
# Test loss: 0.08078, Test accuracy: 0.97402

# %%
from mynn.attack import fgsm_attack
adv_test_images = fgsm_attack(
    model=model, 
    images=test_images, 
    labels=test_labels, 
    loss_fn=loss_fn,
    epsilon=20/255.0  
)

test_set_adv = (adv_test_images, test_labels)

# %%
import numpy as np
print("Min pixel value:", np.min(test_set_adv[0]))
print("Max pixel value:", np.max(test_set_adv[0]))
# Out:
# Min pixel value: 0.0
# Max pixel value: 1.0

# %%
adv_loss, adv_acc = runner.evaluate(test_set_adv, batch_size=64,loss_fn=loss_fn)
print(f"Adversarial Test loss: {adv_loss:.5f}, Test accuracy: {adv_acc:.5f}")
# Out:
# Adversarial Test loss: 2.11900, Test accuracy: 0.42625

# %%
import matplotlib.pyplot as plt
def plot_images(images, labels, title=""):
    """
    显示前五张图片，自动处理 Cupy/NumPy、范围归一化等
    - images: (N, C, H, W)，可为 Cupy 或 NumPy
    - labels: (N,) 或 (N, C)
    """
    fig, axes = plt.subplots(1, 5, figsize=(15, 3))
    fig.suptitle(title)

    for i in range(5):
        ax = axes[i]

        # 取单张图片，并转 (H, W, C)
        img = images[i].transpose(1, 2, 0)

        # 如果是 cupy，则转为 numpy
        if hasattr(img, 'get'):
            img = img.get()

        # 如果像素最大值超过1，说明是 [0, 255]，就归一化
        if img.max() > 1:
            img = img / 255.0

        img = np.clip(img, 0, 1)  # 保险剪裁，防止 overflow

        ax.imshow(img)
        # 标签显示
        label = labels[i]
        label_text = np.argmax(label) if len(label.shape) > 0 and label.shape[0] > 1 else label
        ax.set_title(f"Label: {label_text}")
        ax.axis('off')

    plt.show()

# %%
print("Displaying original images...")
plot_images(test_images, test_labels, title="First 5 Images from Test Set")

print("Displaying adversarial images...")
plot_images(adv_test_images, test_labels, title="First 5 Adversarial Images")
# Out:
# Displaying original images...
# Displaying adversarial images...

# %%
layers = [
    Conv(in_channel=1, out_channel=6, kernel=3, stride=1, padding=1, weight_decay=0.00),
    # BN(normalized_dims=(0, 2, 3), param_shape=(1, 32, 1, 1), weight_decay=0.001),
    Sigmoid(),
    Pooling(kernel=2),

    Conv(in_channel=6, out_channel=16, kernel=3, stride=1, padding=1, weight_decay=0.00),
    # BN(normalized_dims=(0, 2, 3), param_shape=(1, 64, 1, 1), weight_decay=0.001),
    Sigmoid(),
    Pooling(kernel=2),

    Flatten(),
    

    Linear(in_channel=16*7*7, out_channel=120, weight_decay=0.00),
    Linear(in_channel=120, out_channel=84, weight_decay=0.00),
    Linear(in_channel=84, out_channel=10, weight_decay=0.00),
]

# %%
model2     = Model(layers)
optimizer = Adam(model=model2, lr=0.001)
loss_fn   = CrossEntropy(model=model2)
runner2    = RunnerM(model=model2, loss=loss_fn, optimizer=optimizer)

# %%
runner2.train_with_attack(
        train_set=train_set,
        dev_set=dev_set,
        batch_size=64,
        num_epochs=15,
        scheduler=CosineAnnealingLR(
            optimizer=optimizer,
            T_max=5,
            eta_min=1e-5,
        ),
        strategy=EarlyStopping(
            patience=5,
            delta=0.0,
        ),
        epsilon=20/255,
        shuffle=True,
        save_dir='best_models_fgsm'
    )
# Out:
# [Adversarial Train] Epoch 1/15: 100%|██████████| 782/782 [00:37<00:00, 21.04batch/s, accuracy=0.75, loss=1.73]
# train_loss: 0.27072, train_acc: 0.92301
# dev_loss  : 0.24153, dev_acc  : 0.93154
# ### Best model saved to: best_models_fgsm\2025-05-22_20-38-28\best_model.pickle
# ### Best validation accuracy updated: 0.00000 -> 0.93154
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 2/15: 100%|██████████| 782/782 [00:37<00:00, 20.71batch/s, accuracy=0.688, loss=0.603]
# train_loss: 0.17973, train_acc: 0.94582
# dev_loss  : 0.15914, dev_acc  : 0.95322
# ### Best model saved to: best_models_fgsm\2025-05-22_20-38-28\best_model.pickle
# ### Best validation accuracy updated: 0.93154 -> 0.95322
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 3/15: 100%|██████████| 782/782 [00:37<00:00, 21.13batch/s, accuracy=0.938, loss=0.268]
# train_loss: 0.12907, train_acc: 0.96238
# dev_loss  : 0.11840, dev_acc  : 0.96924
# ### Best model saved to: best_models_fgsm\2025-05-22_20-38-28\best_model.pickle
# ### Best validation accuracy updated: 0.95322 -> 0.96924
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 4/15: 100%|██████████| 782/782 [00:37<00:00, 20.86batch/s, accuracy=1, loss=0.0575]
# train_loss: 0.10911, train_acc: 0.96805
# dev_loss  : 0.10154, dev_acc  : 0.97334
# ### Best model saved to: best_models_fgsm\2025-05-22_20-38-28\best_model.pickle
# ### Best validation accuracy updated: 0.96924 -> 0.97334
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 5/15: 100%|██████████| 782/782 [00:37<00:00, 20.87batch/s, accuracy=0.938, loss=0.453]
# train_loss: 0.09337, train_acc: 0.97261
# dev_loss  : 0.08720, dev_acc  : 0.97637
# ### Best model saved to: best_models_fgsm\2025-05-22_20-38-28\best_model.pickle
# ### Best validation accuracy updated: 0.97334 -> 0.97637
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 6/15: 100%|██████████| 782/782 [00:37<00:00, 21.13batch/s, accuracy=0.938, loss=0.45]
# train_loss: 0.08994, train_acc: 0.97363
# dev_loss  : 0.08221, dev_acc  : 0.97793
# ### Best model saved to: best_models_fgsm\2025-05-22_20-38-28\best_model.pickle
# ### Best validation accuracy updated: 0.97637 -> 0.97793
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 7/15: 100%|██████████| 782/782 [00:36<00:00, 21.22batch/s, accuracy=0.875, loss=0.414]
# train_loss: 0.08751, train_acc: 0.97452
# dev_loss  : 0.08201, dev_acc  : 0.97891
# ### Best model saved to: best_models_fgsm\2025-05-22_20-38-28\best_model.pickle
# ### Best validation accuracy updated: 0.97793 -> 0.97891
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 8/15: 100%|██████████| 782/782 [00:37<00:00, 21.09batch/s, accuracy=1, loss=0.109]
# train_loss: 0.08619, train_acc: 0.97484
# dev_loss  : 0.07990, dev_acc  : 0.97910
# ### Best model saved to: best_models_fgsm\2025-05-22_20-38-28\best_model.pickle
# ### Best validation accuracy updated: 0.97891 -> 0.97910
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 9/15: 100%|██████████| 782/782 [00:37<00:00, 20.96batch/s, accuracy=0.812, loss=0.499]
# train_loss: 0.09628, train_acc: 0.97155
# dev_loss  : 0.09299, dev_acc  : 0.97529
# Patience: 1/5
#
# [Adversarial Train] Epoch 10/15: 100%|██████████| 782/782 [00:37<00:00, 20.92batch/s, accuracy=0.938, loss=0.39]
# train_loss: 0.08832, train_acc: 0.97358
# dev_loss  : 0.08145, dev_acc  : 0.97822
# Patience: 2/5
#
# [Adversarial Train] Epoch 11/15: 100%|██████████| 782/782 [00:37<00:00, 20.74batch/s, accuracy=0.875, loss=0.612]
# train_loss: 0.07803, train_acc: 0.97664
# dev_loss  : 0.07740, dev_acc  : 0.97891
# Patience: 3/5
#
# [Adversarial Train] Epoch 12/15: 100%|██████████| 782/782 [00:37<00:00, 21.02batch/s, accuracy=0.938, loss=0.237]
# train_loss: 0.07279, train_acc: 0.97863
# dev_loss  : 0.07218, dev_acc  : 0.97891
# Patience: 4/5
#
# [Adversarial Train] Epoch 13/15: 100%|██████████| 782/782 [00:37<00:00, 20.97batch/s, accuracy=1, loss=0.0273]
# train_loss: 0.07277, train_acc: 0.97847
# dev_loss  : 0.07091, dev_acc  : 0.98047
# ### Best model saved to: best_models_fgsm\2025-05-22_20-38-28\best_model.pickle
# ### Best validation accuracy updated: 0.97910 -> 0.98047
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 14/15: 100%|██████████| 782/782 [00:37<00:00, 20.76batch/s, accuracy=0.938, loss=0.367]
# train_loss: 0.06481, train_acc: 0.97986
# dev_loss  : 0.06730, dev_acc  : 0.98125
# ### Best model saved to: best_models_fgsm\2025-05-22_20-38-28\best_model.pickle
# ### Best validation accuracy updated: 0.98047 -> 0.98125
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 15/15: 100%|██████████| 782/782 [00:37<00:00, 20.85batch/s, accuracy=0.812, loss=0.251]
# train_loss: 0.05733, train_acc: 0.98300
# dev_loss  : 0.05851, dev_acc  : 0.98350
# ### Best model saved to: best_models_fgsm\2025-05-22_20-38-28\best_model.pickle
# ### Best validation accuracy updated: 0.98125 -> 0.98350
# Patience Counter Reset to 0

# %%
test_loss, test_acc = runner2.evaluate(test_set, batch_size=64,loss_fn=loss_fn )
print(f"Test loss: {test_loss:.5f}, Test accuracy: {test_acc:.5f}")
# Out:
# Test loss: 0.05766, Test accuracy: 0.98159

# %%
adv_test_images = fgsm_attack(
    model=model2,
    images=test_images,
    labels=test_labels,
    loss_fn=loss_fn,
    epsilon=20/255
)

test_set_adv = (adv_test_images, test_labels)
adv_loss, adv_acc = runner2.evaluate(test_set_adv, batch_size=64,loss_fn=loss_fn )
print(f"Adversarial Test loss: {adv_loss:.5f}, Test accuracy: {adv_acc:.5f}")
# Out:
# Adversarial Test loss: 0.23166, Test accuracy: 0.92605
