# %%
import argparse
import sys
from torchvision.datasets import MNIST
from mynn.data import mnist_augment, preprocess, basic_mnist_augment, merge_datasets
from mynn.layer import Flatten, Linear, ReLU, He, Conv, Dropout, Pooling, BN
from mynn.loss import CrossEntropy
from mynn import Model
from mynn.optimizer import SGD, Adam, MomentGD
from mynn.runner import RunnerM, EarlyStopping, CosineAnnealingLR
import cupy as cp

# %%
cp.random.seed(42)

train_dataset = MNIST(
        root="dataset",
        train=True,
        transform=basic_mnist_augment(train=True),
        download=False
    )
test_dataset = MNIST(
    root="dataset",
    train=False,
    transform=basic_mnist_augment(train=False),
    download=False
)

# %%
import numpy as np
train_images, train_labels = preprocess(train_dataset)
test_images,  test_labels  = preprocess(test_dataset)
# 
train_images = train_images.astype(np.float32) / 255.0
test_images = test_images.astype(np.float32) / 255.0

train_set = (train_images[:50000], train_labels[:50000])

dev_set   = (train_images[50000:], train_labels[50000:])
test_set  = (test_images, test_labels)

# %%
print(train_images.shape, train_labels.shape)
# Out:
# (60000, 1, 28, 28) (60000, 10)

# %%
import numpy as np
print("Min pixel value:", np.min(test_images))
print("Max pixel value:", np.max(test_images))
# Out:
# Min pixel value: 0.0
# Max pixel value: 1.0

# %%
img, label = train_dataset[0]
print(img.min(), img.max())  # 如果 Normalize 了，范围应该大约在 [-1, 1] 而不是 [0, 255]
# Out:
# tensor(-0.4242) tensor(2.8215)

# %%
# Test 2
layers = [
    Conv(in_channel=1, out_channel=32, kernel=3, stride=1, padding=1, weight_decay=0.001),
    BN(normalized_dims=(0,2,3)),
    ReLU(),
    Pooling(kernel=2),

    Conv(in_channel=32, out_channel=64, kernel=3, stride=1, padding=1, weight_decay=0.001),
    BN(normalized_dims=(0, 2, 3)),
    ReLU(),
    Pooling(kernel=2),

    Flatten(),
    Dropout(rate=0.5),

    Linear(in_channel=64*7*7, out_channel=10, weight_decay=0.001),
]

# %%
model     = Model(layers)
optimizer = Adam(model=model, lr=0.001)
loss_fn   = CrossEntropy(model=model)
runner    = RunnerM(model=model, loss=loss_fn, optimizer=optimizer)

# %%
# 3. 训练
runner.train(
    train_set=train_set,
    dev_set=dev_set,
    batch_size=64,
    num_epochs=5,
    scheduler=CosineAnnealingLR(
        optimizer=optimizer,
        T_max=5,
            eta_min=1e-5,
    ),
    strategy=EarlyStopping(
        patience=5,
        delta=0.0,
    ),
    shuffle=True,
    save_dir='best_models'
)
# Out:
# Epoch 1/5: 100%|██████████| 782/782 [00:44<00:00, 17.71batch/s, accuracy=0.938, loss=0.366]
# train_loss: 0.08897, train_acc: 0.97263
# dev_loss  : 0.08679, dev_acc  : 0.97393
# ### Best model saved to: best_models\2025-05-13_16-38-05\best_model.pickle
# ### Best validation accuracy updated: 0.00000 -> 0.97393
# Patience Counter Reset to 0
#
# Epoch 2/5: 100%|██████████| 782/782 [00:42<00:00, 18.37batch/s, accuracy=1, loss=0.00985]
# train_loss: 0.05715, train_acc: 0.98242
# dev_loss  : 0.06306, dev_acc  : 0.98359
# ### Best model saved to: best_models\2025-05-13_16-38-05\best_model.pickle
# ### Best validation accuracy updated: 0.97393 -> 0.98359
# Patience Counter Reset to 0
#
# Epoch 3/5: 100%|██████████| 782/782 [00:42<00:00, 18.24batch/s, accuracy=1, loss=0.00121]
# train_loss: 0.04246, train_acc: 0.98715
# dev_loss  : 0.05858, dev_acc  : 0.98525
# ### Best model saved to: best_models\2025-05-13_16-38-05\best_model.pickle
# ### Best validation accuracy updated: 0.98359 -> 0.98525
# Patience Counter Reset to 0
#
# Epoch 4/5: 100%|██████████| 782/782 [00:43<00:00, 18.17batch/s, accuracy=0.938, loss=0.0676]
# train_loss: 0.04122, train_acc: 0.98703
# dev_loss  : 0.05957, dev_acc  : 0.98486
# Patience: 1/5
#
# Epoch 5/5: 100%|██████████| 782/782 [00:43<00:00, 18.11batch/s, accuracy=1, loss=0.0189]
# train_loss: 0.03005, train_acc: 0.99063
# dev_loss  : 0.04626, dev_acc  : 0.98799
# ### Best model saved to: best_models\2025-05-13_16-38-05\best_model.pickle
# ### Best validation accuracy updated: 0.98525 -> 0.98799
# Patience Counter Reset to 0

# %%
# 4. 测试集评估
test_loss, test_acc = runner.evaluate(test_set, batch_size=64)
print(f"Test loss: {test_loss:.5f}, Test accuracy: {test_acc:.5f}")
# Out:
# Test loss: 0.03999, Test accuracy: 0.98676

# %%
from mynn.attack import fgsm_attack
adv_test_images = fgsm_attack(
    model=model, 
    images=test_images, 
    labels=test_labels, 
    loss_fn=loss_fn,
    epsilon=20/255.0  
)

test_set_adv = (adv_test_images, test_labels)

# %%
import numpy as np
print("Min pixel value:", np.min(test_set_adv[0]))
print("Max pixel value:", np.max(test_set_adv[0]))
# Out:
# Min pixel value: 0.0
# Max pixel value: 1.0

# %%
adv_loss, adv_acc = runner.evaluate(test_set_adv, batch_size=64)
print(f"Adversarial Test loss: {adv_loss:.5f}, Test accuracy: {adv_acc:.5f}")
# Out:
# Adversarial Test loss: 0.40618, Test accuracy: 0.90844

# %%
import matplotlib.pyplot as plt
def plot_images(images, labels, title=""):
    """
    显示前五张图片，自动处理 Cupy/NumPy、范围归一化等
    - images: (N, C, H, W)，可为 Cupy 或 NumPy
    - labels: (N,) 或 (N, C)
    """
    fig, axes = plt.subplots(1, 5, figsize=(15, 3))
    fig.suptitle(title)

    for i in range(5):
        ax = axes[i]

        # 取单张图片，并转 (H, W, C)
        img = images[i].transpose(1, 2, 0)

        # 如果是 cupy，则转为 numpy
        if hasattr(img, 'get'):
            img = img.get()

        # 如果像素最大值超过1，说明是 [0, 255]，就归一化
        if img.max() > 1:
            img = img / 255.0

        img = np.clip(img, 0, 1)  # 保险剪裁，防止 overflow

        ax.imshow(img)
        # 标签显示
        label = labels[i]
        label_text = np.argmax(label) if len(label.shape) > 0 and label.shape[0] > 1 else label
        ax.set_title(f"Label: {label_text}")
        ax.axis('off')

    plt.show()

# %%
print("Displaying original images...")
plot_images(test_images, test_labels, title="First 5 Images from Test Set")

print("Displaying adversarial images...")
plot_images(adv_test_images, test_labels, title="First 5 Adversarial Images")
# Out:
# Displaying original images...
# Displaying adversarial images...

# %%
layers = [
    Conv(in_channel=1, out_channel=32, kernel=3, stride=1, padding=1, weight_decay=0.001),
    BN(normalized_dims=(0,2,3)),
    ReLU(),
    Pooling(kernel=2),

    Conv(in_channel=32, out_channel=64, kernel=3, stride=1, padding=1, weight_decay=0.001),
    BN(normalized_dims=(0, 2, 3)),
    ReLU(),
    Pooling(kernel=2),

    Flatten(),
    Dropout(rate=0.5),

    Linear(in_channel=64*7*7, out_channel=10, weight_decay=0.001),
]

# %%
model2     = Model(layers)
optimizer = Adam(model=model2, lr=0.001)
loss_fn   = CrossEntropy(model=model2)
runner2    = RunnerM(model=model2, loss=loss_fn, optimizer=optimizer)

# %%
runner2.train_with_attack(
        train_set=train_set,
        dev_set=dev_set,
        batch_size=64,
        num_epochs=5,
        scheduler=CosineAnnealingLR(
            optimizer=optimizer,
            T_max=5,
            eta_min=1e-5,
        ),
        strategy=EarlyStopping(
            patience=5,
            delta=0.0,
        ),
        shuffle=True,
        save_dir='best_models'
    )
# Out:
# [Adversarial Train] Epoch 1/5: 100%|██████████| 782/782 [01:13<00:00, 10.59batch/s, accuracy=1, loss=0.00173]
# train_loss: 0.08037, train_acc: 0.97638
# dev_loss  : 0.08150, dev_acc  : 0.97754
# ### Best model saved to: best_models\2025-05-13_16-25-34\best_model.pickle
# ### Best validation accuracy updated: 0.00000 -> 0.97754
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 2/5: 100%|██████████| 782/782 [01:13<00:00, 10.70batch/s, accuracy=0.938, loss=0.0864]
# train_loss: 0.05448, train_acc: 0.98359
# dev_loss  : 0.06279, dev_acc  : 0.98398
# ### Best model saved to: best_models\2025-05-13_16-25-34\best_model.pickle
# ### Best validation accuracy updated: 0.97754 -> 0.98398
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 3/5: 100%|██████████| 782/782 [01:12<00:00, 10.73batch/s, accuracy=1, loss=0.000288]
# train_loss: 0.05511, train_acc: 0.98268
# dev_loss  : 0.07703, dev_acc  : 0.98164
# Patience: 1/5
#
# [Adversarial Train] Epoch 4/5: 100%|██████████| 782/782 [01:13<00:00, 10.66batch/s, accuracy=1, loss=0.00034]
# train_loss: 0.04234, train_acc: 0.98691
# dev_loss  : 0.05290, dev_acc  : 0.98594
# ### Best model saved to: best_models\2025-05-13_16-25-34\best_model.pickle
# ### Best validation accuracy updated: 0.98398 -> 0.98594
# Patience Counter Reset to 0
#
# [Adversarial Train] Epoch 5/5: 100%|██████████| 782/782 [01:13<00:00, 10.64batch/s, accuracy=1, loss=0.000635]
# train_loss: 0.03177, train_acc: 0.99027
# dev_loss  : 0.04707, dev_acc  : 0.98730
# ### Best model saved to: best_models\2025-05-13_16-25-34\best_model.pickle
# ### Best validation accuracy updated: 0.98594 -> 0.98730
# Patience Counter Reset to 0

# %%
test_loss, test_acc = runner2.evaluate(test_set, batch_size=64)
print(f"Test loss: {test_loss:.5f}, Test accuracy: {test_acc:.5f}")
# Out:
# Test loss: 0.04174, Test accuracy: 0.98696

# %%
adv_test_images = fgsm_attack(
    model=model2,
    images=test_images,
    labels=test_labels,
    loss_fn=loss_fn,
    epsilon=20/255
)

test_set_adv = (adv_test_images, test_labels)
adv_loss, adv_acc = runner2.evaluate(test_set_adv, batch_size=64)
print(f"Adversarial Test loss: {adv_loss:.5f}, Test accuracy: {adv_acc:.5f}")
# Out:
# Adversarial Test loss: 0.32852, Test accuracy: 0.92028
